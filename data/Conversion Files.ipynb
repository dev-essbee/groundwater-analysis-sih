# %%
import pandas as pd

# %%
df=pd.read_excel('datafile(3).xls')
df2=pd.read_excel('datafile(1).xlsx')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df
# Out:
#      YEAR  ANNUAL - MIN  ANNUAL - MAX  JAN-FEB - MIN  JAN-FEB - MAX  \
# 0    1901         19.51         28.96          14.16          23.27
# 1    1902         19.44         29.22          13.64          25.75
# 2    1903         19.25         28.47          13.87          24.24
# 3    1904         19.22         28.49          13.72          23.62
# 4    1905         19.03         28.30          12.81          22.25
# ..    ...           ...           ...            ...            ...
# 112  2013         19.83         29.81          14.38          25.58
# 113  2014         19.77         29.72          14.26          24.90
# 114  2015         19.96         29.90          14.53          25.74
# 115  2016         21.28         31.63          16.17          28.33
# 116  2017         21.17         31.42          15.72          27.95
#
#      MAR-MAY - MIN  MAR-MAY - MAX  JUN-SEP - MIN  JUN-SEP - MAX  \
# 0            20.67          31.46          23.38          31.27
# ...

# %%
df.to_csv('temperature.csv')
df2.to_csv('Temperature.csv')

# %%
a=pd.read_csv('temperature.csv')
b=pd.read_csv('Temperature.csv')

# %%
a
# Out:
#      Unnamed: 0  YEAR  ANNUAL - MIN  ANNUAL - MAX  JAN-FEB - MIN  \
# 0             0  1901         19.51         28.96          14.16
# 1             1  1902         19.44         29.22          13.64
# 2             2  1903         19.25         28.47          13.87
# 3             3  1904         19.22         28.49          13.72
# 4             4  1905         19.03         28.30          12.81
# ..          ...   ...           ...           ...            ...
# 112         112  2013         19.83         29.81          14.38
# 113         113  2014         19.77         29.72          14.26
# 114         114  2015         19.96         29.90          14.53
# 115         115  2016         21.28         31.63          16.17
# 116         116  2017         21.17         31.42          15.72
#
#      JAN-FEB - MAX  MAR-MAY - MIN  MAR-MAY - MAX  JUN-SEP - MIN  \
# 0            23.27          20.67          31.46          23.38
# ...
