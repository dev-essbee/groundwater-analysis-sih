# %%
import pandas as pd

# %%
df=pd.read_csv(r'../data/allgroundwater_District wise Level Report_1594195262229(2012-2020).csv')

# %%
df
# Out:
#     DISTRICTWISE Ground water Level (in m.) Report (<ALL AGENCIES> - <2012> to <2020>)  \
# 0                                                  NaN
# 1                                                STATE
# 2                                       MADHYA PRADESH
# 3                                      JAMMU & KASHMIR
# 4                                                BIHAR
# ..                                                 ...
# 626                                    JAMMU & KASHMIR
# 627                                     ANDHRA PRADESH
# 628                                          RAJASTHAN
# 629                                      UTTAR PRADESH
# 630                                              BIHAR
#
#      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0           NaN       2012       2013       2014       2015       2016
# 1      DISTRICT  Level (m)  Level (m)  Level (m)  Level (m)  Level (m)
# ...
